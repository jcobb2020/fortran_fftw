# %%
import Pkg
Pkg.add("DataFrames")
# Out:
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.1/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.1/Manifest.toml`
#  [no changes]

# %%
using Plots
using DataFrames
Pkg.add("CSV")
using CSV
# Out:
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.1/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.1/Manifest.toml`
#  [no changes]

# %% [markdown]
# Ładujemy pliki pierwszego zadania - przetwarzanie sumy sygnałów

# %%
os1 = CSV.read("res/original_signal_1")
ts1 = CSV.read("res/transformed_signal_1")
# Out:
# 513×2 DataFrame
# │ Row │  col1 │  col2      │
# │     │ Int64 │ Float64    │
# ├─────┼───────┼────────────┤
# │ 1   │ 1     │ 0.00724596 │
# │ 2   │ 2     │ 0.00976704 │
# │ 3   │ 3     │ 0.0149696  │
# │ 4   │ 4     │ 0.020944   │
# │ 5   │ 5     │ 0.0271881  │
# │ 6   │ 6     │ 0.0335538  │
# │ 7   │ 7     │ 0.0399855  │
# │ 8   │ 8     │ 0.0464584  │
# │ 9   │ 9     │ 0.05296    │
# │ 10  │ 10    │ 0.0594836  │
# ⋮
# │ 503 │ 503   │ 6.36853    │
# │ 504 │ 504   │ 6.35987    │
# │ 505 │ 505   │ 6.35215    │
# │ 506 │ 506   │ 6.34535    │
# │ 507 │ 507   │ 6.33947    │
# │ 508 │ 508   │ 6.3345     │
# │ 509 │ 509   │ 6.33045    │
# │ 510 │ 510   │ 6.3273     │
# │ 511 │ 511   │ 6.32505    │
# │ 512 │ 512   │ 6.3237     │
# │ 513 │ 513   │ 6.32325    │

# %% [markdown]
# Przebieg naszego sygnału:

# %%
plot(os1[1], os1[2])

# %% [markdown]
# Sygnał poddany transformacie:

# %%
plot(ts1[1], ts1[2])

# %% [markdown]
# Ładujemy pliki drugiego zadania - oczyszczanie "zaszumianego przebiegu funkcji cosinus"

# %%
os2= CSV.read("res/original_signal_2")
ts2 = CSV.read("res/transformed_signal_2")
rs2 = CSV.read("res/result_signal_2")
# Out:
# 1024×2 DataFrame
# │ Row  │  col1       │  col2    │
# │      │ Float64     │ Float64  │
# ├──────┼─────────────┼──────────┤
# │ 1    │ 0.0         │ 0.99806  │
# │ 2    │ 0.000977517 │ 0.99803  │
# │ 3    │ 0.00195503  │ 0.997962 │
# │ 4    │ 0.00293255  │ 0.997857 │
# │ 5    │ 0.00391007  │ 0.997714 │
# │ 6    │ 0.00488759  │ 0.997534 │
# │ 7    │ 0.0058651   │ 0.997316 │
# │ 8    │ 0.00684262  │ 0.997061 │
# │ 9    │ 0.00782014  │ 0.996768 │
# │ 10   │ 0.00879765  │ 0.996438 │
# ⋮
# │ 1014 │ 0.990225    │ 0.99591  │
# │ 1015 │ 0.991202    │ 0.996293 │
# │ 1016 │ 0.99218     │ 0.996639 │
# │ 1017 │ 0.993157    │ 0.996947 │
# │ 1018 │ 0.994135    │ 0.997218 │
# │ 1019 │ 0.995112    │ 0.997451 │
# │ 1020 │ 0.99609     │ 0.997646 │
# │ 1021 │ 0.997067    │ 0.997804 │
# │ 1022 │ 0.998045    │ 0.997924 │
# │ 1023 │ 0.999022    │ 0.998007 │
# │ 1024 │ 1.0         │ 0.998052 │

# %% [markdown]
# Wykres zaszumionej funkcji cosinus

# %%
plot(os2[1], os2[2], label="znieksztalcony cosinus")

# %% [markdown]
# Wykresy ilustrujące wygląd naszejfunkcji po transformacie

# %%
plot(ts2[1], ts2[2])

# %%
sticks(ts2[2])

# %% [markdown]
# w celu oczysczenia funckji zerujemy wszystkie miejsca w tranformacie które przyjmują wartość < 50

# %% [markdown]
# Dokonujemy odwrotnej transformaty i otrzymujemy wykres oczyszczonej funcji cosinus

# %%
plot(rs2[1], rs2[2], label = "oczyszczony cosinus")

# %% [markdown]
# Pomocny tutorial który mocno pomógł w użyciu FFTW: https://gist.github.com/LadaF/73eb430682ef527eea9972ceb96116c5
